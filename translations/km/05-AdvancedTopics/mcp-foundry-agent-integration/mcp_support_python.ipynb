# %% [markdown]
# # បំណិន AI Azure រួមជាមួយវិធីសាស្រ្ត Model Context Protocol (MCP) - Python
#
# កំណត់ហេតុនេះបង្ហាញពីរបៀបប្រើប្រាស់បំណិន AI Azure រួមជាមួយឧបករណ៍ Model Context Protocol (MCP) ក្នុង Python។ វាបង្ហាញពីរបៀបបង្កើតបំណិនឆ្លាតវៃដែលអាចប្រើប្រាស់ម៉ាស៊ីនម៉ោង MCP ខាងក្រៅ (ដូចជា Microsoft Learn) សម្រាប់កំណត់សមត្ថភាពបន្ថែមដោយប្រើការផ្ទៀងផ្ទាត់គ្មានកូនសោ។

# %% [markdown]
# ## តំឡើងកញ្ចប់ Python ត្រូវការជាមុន
#
# ដំបូង យើងត្រូវតំឡើងកញ្ចប់ Python ដែលចាំបាច់៖
# - **azure-ai-projects**: បណ្ណាល័យមូលដ្ឋាន Azure AI Projects SDK
# - **azure-ai-agents**: បណ្ណាល័យ Azure AI Agents SDK សម្រាប់បង្កើត និងគ្រប់គ្រងភ្នាក់ងារ
# - **azure-identity**: ផ្តល់អត្តសញ្ញាណមិនប្រើកូនសោតាមការប្រើប្រាស់ DefaultAzureCredential
# - **mcp**: ការអនុវត្តប្រព័ន្ធកំណត់បរិបទម៉ូឌែលសម្រាប់ Python

# %% [markdown]
# ## អត្ថប្រយោជន៍នៃការផ្ទៀងផ្ទាត់គ្មានគ្រាប់សោ
#
# ខ្ទង់កំណត់ត្រានេះបង្ហាញពី **ការផ្ទៀងផ្ទាត់គ្មានគ្រាប់សោ** ដែលផ្តល់អត្ថប្រយោជន៍ជាច្រើន៖
# - ✅ **គ្មានគ្រាប់សោ API ត្រូវគ្រប់គ្រង** - ប្រើការផ្ទៀងផ្ទាត់មានមូលដ្ឋានលើអត្តសញ្ញាណ Azure
# - ✅ **សន្តិសុខកាន់តែប្រសើរ** - គ្មានអាថ៌កំបាំងផ្ទុកក្នុងកូដ ឬឯកសារកំណត់រចនា
# - ✅ **ការបង្វិលសញ្ញាប័ត្រដោយស្វ័យប្រវត្តិ** - Azure គ្រប់គ្រងជីវិតលំដាប់សញ្ញាប័ត្រ
# - ✅ **ការត្រួតពិនិត្យចូលដោយផ្អែកលើតួនាទី** - ប្រើ Azure RBAC សម្រាប់ការអនុញ្ញាតយ៉ាងម៉ត់ចត់
# - ✅ **គាំទ្របរិស្ថានច្រើន** - ធ្វើការយ៉ាងរលូនទាំងការអភិវឌ្ឍន៍ និងផលិតកម្ម
#
# `DefaultAzureCredential` ជ្រើសរើសប្រភពសញ្ញាប័ត្រដែលល្អបំផុតដោយស្វ័យប្រវត្តិ៖
# 1. **អត្តសញ្ញាណគ្រប់គ្រង** (ពេលដំណើរការនៅក្នុង Azure)
# 2. សញ្ញាប័ត្រ **Azure CLI** (ក្នុងអំឡុងពេលអភិវឌ្ឍន៍មូលដ្ឋាន)
# 3. សញ្ញាប័ត្រ **Visual Studio**
# 4. **បរិស្ថានអថេរ** (បើបានកំណត់)
# 5. ការផ្ទៀងផ្ទាត់តាមរយៈ **កម្មវិធីរុករកអ៊ីនធឺណက်** (ជាជម្រើសប្លាស់ប្តូរ)

# %% [markdown]
# ## ការដាក់ទ្វារូបភាពបង់គ្មានការផ្ទៀងផ្ទាត់
#
# **លក្ខខណ្ឌមុនសម្រាប់ការផ្ទៀងផ្ទាត់បង់គ្មានកូនសោៈ**
#
# ### សម្រាប់ការអភិវឌ្ឍនៅក្នុងមូលដ្ឋាន:
# ```bash
# # តំឡើង Azure CLI និងចូលក្នុងប្រព័ន្ធ
# az login
# # ពិនិត្យសម្គាល់អត្តសញ្ញាណរបស់អ្នក
# az account show
# ```
#
# ### សម្រាប់បរិយាកាស Azure:
# - បើក **Identity ដែលបានរៀបចំដោយប្រព័ន្ធ** លើធនធាន Azure របស់អ្នក
# - ផ្ដល់តួនាទី **RBAC ដែលសមស្រប** ទៅ identity ដែលបានគ្រប់គ្រង:
#   - `Cognitive Services OpenAI User` សម្រាប់ការចូលប្រើ Azure OpenAI
#   - `AI Developer` សម្រាប់ការចូលប្រើគម្រោង Azure AI
#
# ### មូលដ្ឋានបរិយាកាស (ជាគ្រោះថ្នាក់):
# ```python
# # ទាំងនេះត្រូវបានរកឃើញដោយស្វ័យប្រវត្តិដោយ DefaultAzureCredential
# # AZURE_CLIENT_ID=<លេខសម្គាល់​អតិថិជន​របស់​អ្នក>
# # AZURE_CLIENT_SECRET=<លេខសម្ងាត់​អតិថិជន​របស់​អ្នក>
# # AZURE_TENANT_ID=<លេខសម្គាល់​ជួល​ម្ចាស់​ជាន់​របស់​អ្នក>
# ```
#
# **មិនចាំបាច់មានគ្រាប់ API ឬខ្សែភ្ជាប់ណាមួយទេ!** 🔐

# %%
! pip install azure-ai-projects -U
! pip install azure-ai-agents==1.1.0b4 -U
! pip install azure-identity -U
! pip install mcp==1.11.0 -U

# %% [markdown]
# ## នាំចូលបណ្ណាល័យដែលត្រូវការ
#
# នាំចូលម៉ុឌុល Python ចាំបាច់៖
# - **os, time**: បណ្ណាល័យ Python ស្តង់ដារសម្រាប់អថេរបរិវេណ និងការពន្យារពេល
# - **AIProjectClient**: អតិថិជនសំខាន់សម្រាប់គម្រោង AI របស់ Azure
# - **DefaultAzureCredential**: ការផ្ទៀងផ្ទាត់គ្មានកូនសោសម្រាប់សេវាកម្ម Azure
# - **ថ្នាក់ដែលទាក់ទង MCP**: សម្រាប់បង្កើត និងគ្រប់គ្រងឧបករណ៍ MCP និងដោះសោការអនុម័ត

# %%
import os, time
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential
from azure.ai.agents.models import McpTool, RequiredMcpToolCall, SubmitToolApprovalAction, ToolApproval

# %% [markdown]
# ## កំណត់ការកំណត់ម៉ាស៊ែវ MCP
#
# កំណត់ការកំណត់ម៉ាស៊ែវ MCP ដោយប្រើអថេរពរិយាកាសជាមួយលំនាំដើមបរផ្ទេរ៖
# - **MCP_SERVER_URL**: អាសយដ្ឋាន URL របស់ម៉ាស៊ែវ MCP (លំនាំដើមទៅ Microsoft Learn API)
# - **MCP_SERVER_LABEL**: ស្លាកសញ្ញាដើម្បីកំណត់ម៉ាស៊ែវ MCP (លំនាំដើមជា "mslearn")
#
# វិធីនេះអនុញ្ញាតឲ្យមានការកំណត់ប្ដូរយ៉ាងបត់បែន នៅក្នុងបរិបទផ្សេងៗគ្នា។

# %%
mcp_server_url = os.environ.get("MCP_SERVER_URL", "https://learn.microsoft.com/api/mcp")
mcp_server_label = os.environ.get("MCP_SERVER_LABEL", "mslearn")

# %% [markdown]
# ## បង្កើតអតិថិជនគម្រោង Azure AI (ការផ្ទៀងផ្ទាត់ដោយគ្មាន Key)
#
# ចាប់ផ្ដើមអតិថិជនគម្រោង Azure AI ដោយប្រើ **ការផ្ទៀងផ្ទាត់ដោយគ្មាន key**៖
# - **endpoint**: URL ចុងក្រោយគម្រោង Azure AI Foundry
# - **credential**: ប្រើ `DefaultAzureCredential()` សម្រាប់ការផ្ទៀងផ្ទាត់ដោយគ្មាន key ដែលមានសុវត្ថិភាព
# - **មិនត្រូវការកូន API**: ស្វ័យប្រវត្តិនៅការស្វែងរក និងប្រើកូនសម្សៅល្អបំផុតដែលមានស្រាប់
#
# **ដំណើរការផ្ទៀងផត្ថ់៖**
# 1. ពិនិត្យរក Managed Identity (នៅក្នុងបរិស្ថាន Azure)
# 2. វិលទៅប្រើកូនសម្រង់ Azure CLI (សម្រាប់ការអភិវឌ្ឍក្នុងតំបន់)
# 3. ប្រើប្រភពកូនសម្រង់មានស្រាប់ផ្សេងទៀតនៅពេលចាំបាច់
#
# វិធីសាស្ត្រនេះលុបចោលការប្រើ API key ឬខ្សែភ្ជាប់ក្នុងកូដរបស់អ្នក។

# %%
project_client = AIProjectClient(
    endpoint="Your Azure AI Foundry Endpoint",
    credential=DefaultAzureCredential(),
)

# %% [markdown]
# ## បង្កើតនិយមន័យឧបករណ៍ MCP
#
# បង្កើតឧបករណ៍ MCP មួយដែលភ្ជាប់ទៅម៉ាស៊ីនមេ Microsoft Learn MCP៖
# - **server_label**: ឈ្មោះសម្គាល់សម្រាប់ម៉ាស៊ីនមេ MCP
# - **server_url**: ចំណុចចូល URL របស់ម៉ាស៊ីនមេ MCP
# - **allowed_tools**: បញ្ជីជាជម្រើសដើម្បីកំណត់ឧបករណ៍ណាអាចប្រើបាន (បញ្ជីទទេអនុញ្ញាតឲ្យប្រើឧបករណ៍ទាំងអស់)
#
# ឧបករណ៍នេះនឹងអនុញ្ញាតឲ្យភ្នាក់ងារចូលដំណើរការឯកសារ និងធនធាន Microsoft Learn។

# %%
mcp_tool = McpTool(
    server_label=mcp_server_label,
    server_url=mcp_server_url,
    allowed_tools=[],  # Optional: specify allowed tools
)

# %% [markdown]
# ## បង្កើតភ្នាក់ងារ និងអនុវត្តការសន្ទនា (ចរន្តការងារឥតប្រើគន្លឹះ)
#
# ផ្នែកពេញលេញនេះបង្ហាញពី **ចរន្តការងារភ្នាក់ងារឥតប្រើគន្លឹះ** យ៉ាងទូលំទូលាយ៖
#
# 1. **បង្កើតភ្នាក់ងារ AI**៖ បង្កើតភ្នាក់ងារដោយប្រើម៉ូឌែល GPT-4.1 nano និងឧបករណ៍ MCP
# 2. **បង្កើតខ្សែសង្វាក់**៖ បង្កើតខ្សែសន្ទនាសម្រាប់ការទំនាក់ទំនង
# 3. **ផ្ញើសារ**៖ សួរភ្នាក់ងារអំពីផ្សេងគ្នារវាង Azure OpenAI និង OpenAI
# 4. **គ្រប់គ្រងការអនុម័តឧបករណ៍**៖ អនុម័តការហៅឧបករណ៍ MCP ដោយស្វ័យប្រវត្តិ នៅពេលត្រូវការ
# 5. **ត្រួតពិនិត្យការអនុវត្ត**៖ តាមដានការរីកចម្រើនរបស់ភ្នាក់ងារ និងដោះស្រាយសកម្មភាពដែលត្រូវការ
# 6. **បង្ហាញលទ្ធផល**៖ បង្ហាញសន្ទនា និងព័ត៌មានលម្អិតអំពីការប្រើឧបករណ៍
#
# **លក្ខណៈពិសេសអត់គន្លឹះ៖**
# - ✅ **គ្មានអាជ្ញាបណ្ណជាក់លាក់** - ការផ្ទៀងផ្ទាត់គឺដោយអត្តសញ្ញាណ Azure ទៅវិញទៅមក
# - ✅ **សុវត្ថិភាពដោយលំនាំដើម** - ប្រើការគ្រប់គ្រងចូលដោយតម្រូវតួអង្គ
# - ✅ **បញ្ចេញយ៉ាងងាយស្រួល** - មិនចាំបាច់គ្រប់គ្រងព័ត៌មានសម្គាល់
# - ✅ **ងាយស្រួលត្រួតពិនិត្យ** - ការចូលប្រើទាំងអស់ត្រូវបានតាមដានតាមអត្តសញ្ញាណ Azure
#
# ភ្នាក់ងារនេះនឹងប្រើឧបករណ៍ MCP ដើម្បីចូលប្រើធនធាន Microsoft Learn ជាមួយសុវត្ថិភាពពេញលេញ ហើយមិនចាំបាច់គ្រប់គ្រងកូនសោ API ទេ។

# %%
with project_client:
    agents_client = project_client.agents

    # Create a new agent with keyless authentication
    # NOTE: To reuse existing agent, fetch it with get_agent(agent_id)
    agent = agents_client.create_agent(
        model="Your Azure OpenAI Model Deployment Name",
        name="my-mcp-agent",
        instructions="You are a helpful agent that can use MCP tools to assist users. Use the available MCP tools to answer questions and perform tasks.",
        tools=mcp_tool.definitions,
    )
    print(f"Created agent, ID: {agent.id}")
    print(f"MCP Server: {mcp_tool.server_label} at {mcp_tool.server_url}")

    # Create thread for communication
    thread = agents_client.threads.create()
    print(f"Created thread, ID: {thread.id}")

    # Create message to thread
    message = agents_client.messages.create(
        thread_id=thread.id,
        role="user",
        content="What's difference between Azure OpenAI and OpenAI?",
    )
    print(f"Created message, ID: {message.id}")

    # KEYLESS APPROACH: Handle tool approvals without hardcoded secrets
    
    # Option 1: Completely keyless (recommended for Azure identity-enabled MCP servers)
    # run = agents_client.runs.create(thread_id=thread.id, agent_id=agent.id, tool_resources=mcp_tool.resources)
    
    # Option 2: With minimal headers (if MCP server requires specific headers)
    # For demonstration purposes, using a placeholder header
    mcp_tool.update_headers("SuperSecret", "123456")  # Replace with actual auth if needed
    
    # Set approval mode - uncomment next line to disable approval requirement completely
    # mcp_tool.set_approval_mode("never")  # Fully automated, no approval needed
    
    run = agents_client.runs.create(thread_id=thread.id, agent_id=agent.id, tool_resources=mcp_tool.resources)
    print(f"Created run, ID: {run.id}")

    while run.status in ["queued", "in_progress", "requires_action"]:
        time.sleep(1)
        run = agents_client.runs.get(thread_id=thread.id, run_id=run.id)

        if run.status == "requires_action" and isinstance(run.required_action, SubmitToolApprovalAction):
            tool_calls = run.required_action.submit_tool_approval.tool_calls
            if not tool_calls:
                print("No tool calls provided - cancelling run")
                agents_client.runs.cancel(thread_id=thread.id, run_id=run.id)
                break

            tool_approvals = []
            for tool_call in tool_calls:
                if isinstance(tool_call, RequiredMcpToolCall):
                    try:
                        print(f"Approving tool call: {tool_call}")
                        
                        # KEYLESS APPROVAL OPTIONS:
                        
                        # Option 1: No headers (fully keyless)
                        # tool_approvals.append(
                        #     ToolApproval(
                        #         tool_call_id=tool_call.id,
                        #         approve=True,
                        #         headers={}  # No headers needed for keyless
                        #     )
                        # )
                        
                        # Option 2: With headers (if MCP server requires them)
                        tool_approvals.append(
                            ToolApproval(
                                tool_call_id=tool_call.id,
                                approve=True,
                                headers=mcp_tool.headers,  # Uses configured headers if needed
                            )
                        )
                    except Exception as e:
                        print(f"Error approving tool_call {tool_call.id}: {e}")

            print(f"tool_approvals: {tool_approvals}")
            if tool_approvals:
                agents_client.runs.submit_tool_outputs(
                    thread_id=thread.id, run_id=run.id, tool_approvals=tool_approvals
                )

        print(f"Current run status: {run.status}")

    print(f"Run completed with status: {run.status}")
    if run.status == "failed":
        print(f"Run failed: {run.last_error}")

    # Display run steps and tool calls
    run_steps = agents_client.run_steps.list(thread_id=thread.id, run_id=run.id)

    # Loop through each step
    for step in run_steps:
        print(f"Step {step['id']} status: {step['status']}")

        # Check if there are tool calls in the step details
        step_details = step.get("step_details", {})
        tool_calls = step_details.get("tool_calls", [])

        if tool_calls:
            print("  MCP Tool calls:")
            for call in tool_calls:
                print(f"    Tool Call ID: {call.get('id')}")
                print(f"    Type: {call.get('type')}")

        print()  # add an extra newline between steps

    # Fetch and log all messages
    messages = agents_client.messages.list(thread_id=thread.id)
    print("\nConversation:")
    print("-" * 50)
    for msg in messages:
        if msg.text_messages:
            last_text = msg.text_messages[-1]
            print(f"{msg.role.upper()}: {last_text.text.value}")
            print("-" * 50)

    # Example of dynamic tool management (keyless)
    print(f"\nDemonstrating keyless dynamic tool management:")
    print(f"Current allowed tools: {mcp_tool.allowed_tools}")
    print("✅ All operations completed using keyless authentication!")

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **ការបដិសេធ**:
# ឯកសារនេះបានបកប្រែដោយប្រើសេវាបកប្រែ AI [Co-op Translator](https://github.com/Azure/co-op-translator)។ ខណៈដែលយើងខិតខំរកបានភាពត្រឹមត្រូវ សូមយល់ព្រមថាការបកប្រែដោយស្វ័យប្រវត្តិអាចមានកំហុស ឬភាពមិនត្រឹមត្រូវ។ ឯកសារដើមនៅភាសាមាត្ររបស់វាគួរត្រូវបានចាត់ទុកជាធនធានដែលមានអំណាច។ សម្រាប់ព័ត៌មានសំខាន់ៗ ការបកប្រែដោយមនុស្សជំនាញត្រូវបានផ្តល់អនុសាសន៍។ យើងមិនទទួលខុសត្រូវចំពោះការយល់ច្រឡំ ឬការបកប្រែខុសៗដែលកើតឡើងពីការប្រើប្រាស់ការបកប្រែនេះឡើយ។
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
